# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
cities
# Out:
# ['marondera',
#  'hermanus',
#  'illoqqortoormiut',
#  'vaini',
#  'sena madureira',
#  'tuy hoa',
#  'ribeira grande',
#  'kodiak',
#  'punta arenas',
#  'albany',
#  'jiuquan',
#  'rikitea',
#  'port elizabeth',
#  'carbonia',
#  'hithadhoo',
#  'salinopolis',
#  'tasiilaq',
#  'eunice',
#  'port alfred',
#  'busselton',
#  'ovalle',
#  'kaitangata',
#  'puerto ayora',
#  'taolanaro',
#  'jamestown',
#  'port moresby',
#  'yulara',
#  'port-cartier',
#  'tiznit',
#  'garwolin',
#  'mys shmidta',
#  'high level',
#  'tarudant',
#  'sao mateus',
#  'mataura',
#  'iracoubo',
#  'puerto penasco',
#  'mayumba',
#  'fairbanks',
#  'ashukino',
#  'kavaratti',
#  'sorland',
#  'rawson',
#  'bengkulu',
#  'vila franca do campo',
#  'saint-augustin',
#  'necochea',
#  'verkh-usugli',
#  'carnarvon',
#  'provideniya',
#  'nanortalik',
#  'khislavichi',
#  'yellowknife',
#  'kapaa',
#  'tiksi',
#  'nikolskoye',
#  'bluff',
#  'mangaratiba',
#  'ugoofaaru',
#  'nizhneyansk',
#  'batagay-alyta',
#  'nioro',
#  'adrar',
#  'buraydah',
#  'kurchum',
#  'sarakhs',
#  'kysyl-syr',
#  'sechura',
#  'tuatapere',
#  'sitka',
#  'vuktyl',
#  'barrow',
#  'salme',
#  'muscat',
#  'nikolayevsk-na-amure',
#  'longlac',
#  'georgetown',
#  'viedma',
#  'roskovec',
#  'saint-pierre',
#  'matara',
#  'atar',
#  'fukue',
#  'atuona',
#  'mar del plata',
#  'vargem grande',
#  'ushuaia',
#  'nerchinskiy zavod',
#  'orsk',
#  'saldanha',
#  'mazurivka',
#  'attawapiskat',
#  'turbat',
#  'qaqortoq',
#  'raudeberg',
#  'songjianghe',
#  'vestmannaeyjar',
#  'hofn',
#  'floro',
#  'hilo',
#  'bredasdorp',
#  'saint george',
#  'touros',
#  'ciudad bolivar',
#  'faya',
#  'aklavik',
#  'haapu',
#  'evensk',
#  'macomer',
#  'lulea',
#  'ittiri',
#  'butaritari',
#  'ruteng',
#  'lasa',
#  'chiang klang',
#  'new norfolk',
#  'chokurdakh',
#  'salalah',
#  'lebu',
#  'fortuna',
#  'hobart',
#  'roma',
#  'barentsburg',
#  'gobabis',
#  'sanming',
#  'aflu',
#  'lazurne',
#  'portland',
#  'maragogi',
#  'nome',
#  'chingirlau',
#  'svetlaya',
#  'khatanga',
#  'port lincoln',
#  'san cristobal',
#  'basar',
#  'kutum',
#  'jurado',
#  'hami',
#  'harrisonburg',
#  'bathsheba',
#  'severodvinsk',
#  'myski',
#  'zalakomar',
#  'tuktoyaktuk',
#  'nuuk',
#  'kuala terengganu',
#  'sassandra',
#  'moree',
#  'gambela',
#  'longyearbyen',
#  'san carlos de bariloche',
#  'cape town',
#  'shirokiy',
#  'ust-omchug',
#  'saint-philippe',
#  'cabedelo',
#  'comodoro rivadavia',
#  'la ronge',
#  'bretten',
#  'toropets',
#  'kavieng',
#  'cherskiy',
#  'yeppoon',
#  'abapo',
#  'nagato',
#  'nizwa',
#  'bom jesus',
#  'tautira',
#  'shahr-e kord',
#  'vao',
#  'nakamura',
#  'camopi',
#  'vaitupu',
#  'tukrah',
#  'esperance',
#  'nantucket',
#  'lavrentiya',
#  'bethel',
#  'umzimvubu',
#  'port hardy',
#  'chuy',
#  'qaanaaq',
#  'doctor pedro p. pena',
#  'zhovkva',
#  'axim',
#  'saskylakh',
#  'lima',
#  'samusu',
#  'porto torres',
#  'stoyba',
#  'sur',
#  'cidreira',
#  'bakuriani',
#  'chilca',
#  'kapuskasing',
#  'mayna',
#  'saint-louis',
#  'vysha',
#  'nanakuli',
#  'belushya guba',
#  'college',
#  'coihaique',
#  'sibolga',
#  'indiana',
#  'arawa',
#  'huazolotitlan',
#  'wanning',
#  'caravelas',
#  'san rafael',
#  'norman wells',
#  'ponta do sol',
#  'santa cruz',
#  'dzaoudzi',
#  'orotukan',
#  'thompson',
#  'lotofaga',
#  'chicama',
#  'guangyuan',
#  'yerbogachen',
#  'naze',
#  'muhos',
#  'kirovskiy',
#  'te anau',
#  'stillwater',
#  'dunkirk',
#  'talnakh',
#  'sentyabrskiy',
#  'lensk',
#  'lazaro cardenas',
#  'gidole',
#  'chambas',
#  'cabo san lucas',
#  'maceio',
#  'skibbereen',
#  'gurskoye',
#  'kibaya',
#  'fort nelson',
#  'basco',
#  'praia da vitoria',
#  'torbay',
#  'dibrugarh',
#  'tessalit',
#  'acapulco',
#  'tidore',
#  'barcelos',
#  'ilulissat',
#  'ojinaga',
#  'road town',
#  'sisimiut',
#  'vyazemskiy',
#  'leh',
#  'bardiyah',
#  'sturgis',
#  'broken hill',
#  'gorgan',
#  'pevek',
#  'takoradi',
#  'arraial do cabo',
#  'tsihombe',
#  'palmer',
#  'kambove',
#  'aljezur',
#  'narsaq',
#  'hastings',
#  'chillicothe',
#  'napanee',
#  'traralgon',
#  'cumra',
#  'avarua',
#  'ushtobe',
#  'banjar',
#  'westerland',
#  'tabiauea',
#  'katsuura',
#  'klaksvik',
#  'aswan',
#  'brae',
#  'sao joao da barra',
#  'kruisfontein',
#  'souillac',
#  'mogochin',
#  'kizu',
#  'matagami',
#  'richards bay',
#  'victoria',
#  'antofagasta',
#  'constantine',
#  'kisangani',
#  'zaraza',
#  'westport',
#  'hamilton',
#  'dingle',
#  'tonota',
#  'vila',
#  'naryan-mar',
#  'kahului',
#  'katsiveli',
#  'hasaki',
#  'san ramon de la nueva oran',
#  'samarai',
#  'bilkha',
#  'poum',
#  'lolua',
#  'trincomalee',
#  'hartford',
#  'pont-saint-esprit',
#  'warrnambool',
#  'itambe',
#  'castro',
#  'east london',
#  'airai',
#  'nan',
#  'kalmunai',
#  'zhangye',
#  'nam tha',
#  'zaltan',
#  'salina cruz',
#  'ola',
#  'mandan',
#  'bani walid',
#  'khani',
#  'grindavik',
#  'ambodifototra',
#  'juegang',
#  'mahajanga',
#  'karpathos',
#  'esil',
#  'la union',
#  'namatanai',
#  'cabra',
#  'tortoli',
#  'gimbi',
#  'luderitz',
#  'constitucion',
#  'butterworth',
#  'mikkeli',
#  'vera cruz',
#  'midland',
#  'mahebourg',
#  'igboho',
#  'aketi',
#  'hope',
#  'weinan',
#  'ngukurr',
#  'upleta',
#  'palabuhanratu',
#  'hervey bay',
#  'plettenberg bay',
#  'xghajra',
#  'jalu',
#  'bambous virieux',
#  'ixtapa',
#  'chardara',
#  'avera',
#  'kununurra',
#  'tongliao',
#  'dongsheng',
#  'voh',
#  'mosquera',
#  'dikson',
#  'san juan',
#  'green river',
#  'lumeje',
#  'aksarka',
#  'boa vista',
#  'amderma',
#  'severo-kurilsk',
#  'tilichiki',
#  'alofi',
#  'carthage',
#  'upernavik',
#  'chandbali',
#  'ternate',
#  'nadym',
#  'ambilobe',
#  'paraiso',
#  'la cruz',
#  'dauphin',
#  'chenzhou',
#  'chagda',
#  'altamura',
#  'voznesenye',
#  'san patricio',
#  'taksimo',
#  'san fernando',
#  'puhja',
#  'burnie',
#  'pandan',
#  'namibe',
#  'graham',
#  'bonito',
#  'grand river south east',
#  'san andres',
#  'bilma',
#  'osypenko',
#  'hualmay',
#  'afmadu',
#  'jumla',
#  'los llanos de aridane',
#  'vagay',
#  'berlevag',
#  'sainte-anne-des-monts',
#  'visegrad',
#  'zhigalovo',
#  'chapais',
#  'sambava',
#  'sataua',
#  'berezanka',
#  'rapid valley',
#  'puerto madero',
#  'hihifo',
#  'ancud',
#  'kargopol',
#  'pitimbu',
#  'yantal',
#  'san lorenzo',
#  'tefe',
#  'victoria point',
#  'novopokrovka',
#  'rio grande',
#  'mercedes',
#  'rugby',
#  'kamenka',
#  'venice',
#  'alice springs',
#  'lodwar',
#  'lorengau',
#  'porto novo',
#  'nabire',
#  'honiara',
#  'jieshi',
#  'manta',
#  'rafaela',
#  'nuevo ideal',
#  'aripuana',
#  'qandala',
#  'half moon bay',
#  'hohhot',
#  'saleaula',
#  'vung tau',
#  'kaeo',
#  'uk',
#  'lubbock',
#  'igarape-miri',
#  'san quintin',
#  'yaan',
#  'genhe',
#  'kamaishi',
#  'leningradskiy',
#  'areosa',
#  'thinadhoo',
#  'zeya',
#  'kosh-agach',
#  'mezen',
#  'aloleng',
#  'bonthe',
#  'north bend',
#  'marawi',
#  'strezhevoy',
#  'bensonville',
#  'hurghada',
#  'clyde river',
#  'salinas',
#  'taoudenni',
#  'timizart',
#  'bolobo',
#  'abu samrah',
#  'korla',
#  'bondo',
#  'port macquarie',
#  'broome',
#  'gatesville',
#  'bereznik',
#  'karaul',
#  'aykhal',
#  'mujiayingzi',
#  'ambovombe',
#  'pizarro',
#  'ust-kulom',
#  'kanye',
#  'sabang',
#  'dakoro',
#  'kaitong',
#  'chernyshevskiy',
#  'ewa beach',
#  'peniche',
#  'muros',
#  'kamenskoye',
#  'mount gambier',
#  'saint-leu',
#  'kosa',
#  'saint-francois',
#  'garowe',
#  'lakselv',
#  'bartica',
#  'beidao',
#  'dunedin',
#  'eyl',
#  'yuli',
#  'srednekolymsk',
#  'bac lieu',
#  'mana',
#  'okhotsk',
#  'mula',
#  'iqaluit',
#  'kauhajoki',
#  'walvis bay',
#  'santa luzia',
#  'grand gaube',
#  'tuggurt',
#  'hovd',
#  'calizo',
#  'kirakira',
#  'ostrovnoy',
#  'xapuri',
#  'quatre cocos',
#  'iralaya',
#  'bunia',
#  'nouakchott',
#  'cape girardeau',
#  'ekibastuz',
#  'jose bonifacio',
#  'komsomolskiy',
#  'waitati',
#  'nadvoitsy',
#  'pout',
#  'itarema',
#  'impfondo',
#  'port-gentil',
#  'namie',
#  'montijo',
#  'mount isa',
#  'coron',
#  'huarmey',
#  'saint anthony',
#  'emerald',
#  'tura',
#  'tanhacu',
#  'caconda',
#  'flinders',
#  'jambi',
#  'miraflores',
#  'nemuro',
#  'zhenhai',
#  'umm durman',
#  'satitoa',
#  'la rioja',
#  'san jose',
#  'portage',
#  'tumannyy',
#  'karratha',
#  'bay saint louis',
#  'codrington',
#  'wamba',
#  'weihai',
#  'halalo',
#  'tucuman',
#  'gilbues',
#  'yar-sale',
#  'katherine',
#  'kwekwe',
#  'ilhabela',
#  'smithers',
#  'claveria',
#  'yangjiang',
#  'mahaicony',
#  'vrangel',
#  'malinovoye ozero',
#  'marathon',
#  'masvingo',
#  'imbituba',
#  'colac',
#  'hayrabolu',
#  'bati',
#  'kieta',
#  'ndola',
#  'longhua',
#  'alexandria',
#  'belyy yar',
#  'baykit',
#  'itaituba',
#  'sita road',
#  'moyale',
#  'olafsvik',
#  'sao filipe',
#  'chinsali',
#  'gat',
#  'asau',
#  'yarada',
#  'copperas cove',
#  'havelock',
#  'taltal',
#  'egvekinot',
#  'pangai',
#  'babanusah',
#  'dinsor',
#  'moranbah',
#  'kumluca',
#  'rungata',
#  'linfen',
#  'burica',
#  'arequipa',
#  'ossora',
#  'tateyama',
#  'pella',
#  'bahile',
#  'meadow lake',
#  'mehamn',
#  'kachiry',
#  'puerto colombia',
#  'wewak',
#  'sirjan',
#  'awbari',
#  'verkhnevilyuysk',
#  'sakaiminato',
#  'crestview',
#  'general pico',
#  'husavik',
#  'izhmorskiy',
#  'lagoa',
#  'florianopolis',
#  'kazalinsk',
#  'vanimo',
#  'oranjestad',
#  'lindi',
#  'batagay',
#  'coos bay',
#  'haines junction',
#  'montecristi',
#  'atambua',
#  'tadine',
#  'romny',
#  'lubango',
#  'lincoln',
#  'tecoanapa',
#  'saint-pacome',
#  'cayenne',
#  'aboso',
#  'lompoc',
#  'batticaloa',
#  'kishi',
#  'piacabucu',
#  'xuddur',
#  'makakilo city',
#  'oranjemund',
#  'rawannawi',
#  'huaraz',
#  'kasongo',
#  'padang',
#  'beringovskiy']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists to hold data

lat = []
lon = []
max_temp = []
humidity = []
wind_speed = []
cloudiness = []
country = []
date = []
name = []
index_number = 0
set_number = 1

print("Beginning Data Retrieval")     
print("-----------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    url = "http://api.openweathermap.org/data/2.5/weather?"
    units = "imperial"

    # partial query URL
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    try:
        print(f"Processing Record {index_number} of Set {set_number} | {city}")
        
        response = requests.get(query_url + city).json()
        
        #add weather data for city into lists
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        name.append(response['name'])
        
        if index_number == 49:
            #reset record number to 0
            city_number = 0
            #increase set number by 1
            index_number += 1
        else:
            #increase record number by 1            
            index_number += 1
            
    except:
        print(f"City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | marondera
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | sena madureira
# Processing Record 4 of Set 1 | tuy hoa
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | jiuquan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | carbonia
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | salinopolis
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | eunice
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | ovalle
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | port moresby
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | port-cartier
# Processing Record 26 of Set 1 | tiznit
# Processing Record 27 of Set 1 | garwolin
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | high level
# Processing Record 29 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 1 | sao mateus
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | iracoubo
# Processing Record 32 of Set 1 | puerto penasco
# Processing Record 33 of Set 1 | mayumba
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | ashukino
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | sorland
# Processing Record 38 of Set 1 | rawson
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | saint-augustin
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | verkh-usugli
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | khislavichi
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | tiksi
# Processing Record 51 of Set 1 | nikolskoye
# Processing Record 52 of Set 1 | bluff
# Processing Record 53 of Set 1 | mangaratiba
# Processing Record 54 of Set 1 | ugoofaaru
# Processing Record 55 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 55 of Set 1 | batagay-alyta
# Processing Record 56 of Set 1 | nioro
# Processing Record 57 of Set 1 | adrar
# Processing Record 58 of Set 1 | buraydah
# Processing Record 59 of Set 1 | kurchum
# Processing Record 60 of Set 1 | sarakhs
# Processing Record 61 of Set 1 | kysyl-syr
# Processing Record 62 of Set 1 | sechura
# Processing Record 63 of Set 1 | tuatapere
# Processing Record 64 of Set 1 | sitka
# Processing Record 65 of Set 1 | vuktyl
# Processing Record 66 of Set 1 | barrow
# Processing Record 67 of Set 1 | salme
# Processing Record 68 of Set 1 | muscat
# Processing Record 69 of Set 1 | nikolayevsk-na-amure
# Processing Record 70 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 70 of Set 1 | georgetown
# Processing Record 71 of Set 1 | viedma
# Processing Record 72 of Set 1 | roskovec
# Processing Record 73 of Set 1 | saint-pierre
# Processing Record 74 of Set 1 | matara
# Processing Record 75 of Set 1 | atar
# Processing Record 76 of Set 1 | fukue
# Processing Record 77 of Set 1 | atuona
# Processing Record 78 of Set 1 | mar del plata
# Processing Record 79 of Set 1 | vargem grande
# Processing Record 80 of Set 1 | ushuaia
# Processing Record 81 of Set 1 | nerchinskiy zavod
# Processing Record 82 of Set 1 | orsk
# Processing Record 83 of Set 1 | saldanha
# Processing Record 84 of Set 1 | mazurivka
# Processing Record 85 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 85 of Set 1 | turbat
# Processing Record 86 of Set 1 | qaqortoq
# Processing Record 87 of Set 1 | raudeberg
# Processing Record 88 of Set 1 | songjianghe
# Processing Record 89 of Set 1 | vestmannaeyjar
# Processing Record 90 of Set 1 | hofn
# Processing Record 91 of Set 1 | floro
# Processing Record 92 of Set 1 | hilo
# Processing Record 93 of Set 1 | bredasdorp
# Processing Record 94 of Set 1 | saint george
# Processing Record 95 of Set 1 | touros
# Processing Record 96 of Set 1 | ciudad bolivar
# Processing Record 306 of Set 1 | constitucion
# Processing Record 307 of Set 1 | butterworth
# Processing Record 308 of Set 1 | mikkeli
# Processing Record 309 of Set 1 | vera cruz
# Processing Record 310 of Set 1 | midland
# Processing Record 311 of Set 1 | mahebourg
# Processing Record 312 of Set 1 | igboho
# Processing Record 313 of Set 1 | aketi
# Processing Record 314 of Set 1 | hope
# Processing Record 315 of Set 1 | weinan
# Processing Record 316 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 316 of Set 1 | upleta
# Processing Record 317 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 317 of Set 1 | hervey bay
# Processing Record 318 of Set 1 | plettenberg bay
# Processing Record 319 of Set 1 | xghajra
# City not found. Skipping...
# Processing Record 319 of Set 1 | jalu
# Processing Record 320 of Set 1 | bambous virieux
# Processing Record 321 of Set 1 | ixtapa
# Processing Record 322 of Set 1 | chardara
# Processing Record 323 of Set 1 | avera
# Processing Record 324 of Set 1 | kununurra
# Processing Record 325 of Set 1 | tongliao
# Processing Record 326 of Set 1 | dongsheng
# Processing Record 327 of Set 1 | voh
# Processing Record 328 of Set 1 | mosquera
# Processing Record 329 of Set 1 | dikson
# Processing Record 330 of Set 1 | san juan
# Processing Record 331 of Set 1 | green river
# Processing Record 332 of Set 1 | lumeje
# Processing Record 333 of Set 1 | aksarka
# Processing Record 334 of Set 1 | boa vista
# Processing Record 335 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 335 of Set 1 | severo-kurilsk
# Processing Record 336 of Set 1 | tilichiki
# Processing Record 337 of Set 1 | alofi
# Processing Record 338 of Set 1 | carthage
# Processing Record 339 of Set 1 | upernavik
# Processing Record 340 of Set 1 | chandbali
# Processing Record 341 of Set 1 | ternate
# Processing Record 342 of Set 1 | nadym
# Processing Record 343 of Set 1 | ambilobe
# Processing Record 344 of Set 1 | paraiso
# Processing Record 345 of Set 1 | la cruz
# Processing Record 346 of Set 1 | dauphin
# Processing Record 347 of Set 1 | chenzhou
# Processing Record 348 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 348 of Set 1 | altamura
# Processing Record 349 of Set 1 | voznesenye
# Processing Record 350 of Set 1 | san patricio
# Processing Record 351 of Set 1 | taksimo
# Processing Record 352 of Set 1 | san fernando
# Processing Record 353 of Set 1 | puhja
# Processing Record 354 of Set 1 | burnie
# Processing Record 355 of Set 1 | pandan
# Processing Record 356 of Set 1 | namibe
# Processing Record 357 of Set 1 | graham
# Processing Record 358 of Set 1 | bonito
# Processing Record 359 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 359 of Set 1 | san andres
# Processing Record 360 of Set 1 | bilma
# Processing Record 361 of Set 1 | osypenko
# Processing Record 362 of Set 1 | hualmay
# Processing Record 363 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 363 of Set 1 | jumla
# Processing Record 364 of Set 1 | los llanos de aridane
# Processing Record 365 of Set 1 | vagay
# Processing Record 366 of Set 1 | berlevag
# Processing Record 367 of Set 1 | sainte-anne-des-monts
# Processing Record 368 of Set 1 | visegrad
# Processing Record 369 of Set 1 | zhigalovo
# Processing Record 370 of Set 1 | chapais
# Processing Record 371 of Set 1 | sambava
# Processing Record 372 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 372 of Set 1 | berezanka
# Processing Record 373 of Set 1 | rapid valley
# Processing Record 374 of Set 1 | puerto madero
# Processing Record 375 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record
of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 447 of Set 1 | mount gambier
# Processing Record 448 of Set 1 | saint-leu
# Processing Record 449 of Set 1 | kosa
# Processing Record 450 of Set 1 | saint-francois
# Processing Record 451 of Set 1 | garowe
# Processing Record 452 of Set 1 | lakselv
# Processing Record 453 of Set 1 | bartica
# Processing Record 454 of Set 1 | beidao
# Processing Record 455 of Set 1 | dunedin
# Processing Record 456 of Set 1 | eyl
# Processing Record 457 of Set 1 | yuli
# Processing Record 458 of Set 1 | srednekolymsk
# Processing Record 459 of Set 1 | bac lieu
# Processing Record 460 of Set 1 | mana
# Processing Record 461 of Set 1 | okhotsk
# Processing Record 462 of Set 1 | mula
# Processing Record 463 of Set 1 | iqaluit
# Processing Record 464 of Set 1 | kauhajoki
# Processing Record 465 of Set 1 | walvis bay
# Processing Record 466 of Set 1 | santa luzia
# Processing Record 467 of Set 1 | grand gaube
# Processing Record 468 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 468 of Set 1 | hovd
# Processing Record 469 of Set 1 | calizo
# Processing Record 470 of Set 1 | kirakira
# Processing Record 471 of Set 1 | ostrovnoy
# Processing Record 472 of Set 1 | xapuri
# Processing Record 473 of Set 1 | quatre cocos
# Processing Record 474 of Set 1 | iralaya
# Processing Record 475 of Set 1 | bunia
# Processing Record 476 of Set 1 | nouakchott
# Processing Record 477 of Set 1 | cape girardeau
# Processing Record 478 of Set 1 | ekibastuz
# Processing Record 479 of Set 1 | jose bonifacio
# Processing Record 480 of Set 1 | komsomolskiy
# Processing Record 481 of Set 1 | waitati
# Processing Record 482 of Set 1 | nadvoitsy
# Processing Record 483 of Set 1 | pout
# Processing Record 484 of Set 1 | itarema
# Processing Record 485 of Set 1 | impfondo
# Processing Record 486 of Set 1 | port-gentil
# Processing Record 487 of Set 1 | namie
# Processing Record 488 of Set 1 | montijo
# Processing Record 489 of Set 1 | mount isa
# Processing Record 490 of Set 1 | coron
# Processing Record 491 of Set 1 | huarmey
# Processing Record 492 of Set 1 | saint anthony
# Processing Record 493 of Set 1 | emerald
# Processing Record 494 of Set 1 | tura
# Processing Record 495 of Set 1 | tanhacu
# Processing Record 496 of Set 1 | caconda
# Processing Record 497 of Set 1 | flinders
# Processing Record 498 of Set 1 | jambi
# Processing Record 499 of Set 1 | miraflores
# Processing Record 500 of Set 1 | nemuro
# Processing Record 501 of Set 1 | zhenhai
# Processing Record 502 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 502 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 502 of Set 1 | la rioja
# Processing Record 503 of Set 1 | san jose
# Processing Record 504 of Set 1 | portage
# Processing Record 505 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 505 of Set 1 | karratha
# Processing Record 506 of Set 1 | bay saint louis
# Processing Record 507 of Set 1 | codrington
# Processing Record 508 of Set 1 | wamba
# Processing Record 509 of Set 1 | weihai
# Processing Record 510 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 510 of Set 1 | tucuman
# Processing Record 511 of Set 1 | gilbues
# Processing Record 512 of Set 1 | yar-sale
# Processing Record 513 of Set 1 | katherine
# Processing Record 514 of Set 1 | kwekwe
# Processing Record 515 of Set 1 | ilhabela
# Processing Record 516 of Set 1 | smithers
# Processing Record 517 of Set 1 | claveria
# Processing Record 518 of Set 1 | yangjiang
# Processing Record 519 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record
of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 592 of Set 1 | huaraz
# Processing Record 593 of Set 1 | kasongo
# Processing Record 594 of Set 1 | padang
# Processing Record 595 of Set 1 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe from data in lists
weather_api_dict = {
                    "lat": lat,
                    "lon": lon,
                    "max_temp": max_temp,
                    "humidity": humidity,
                    "wind_speed": wind_speed,
                    "cloudiness": cloudiness,
                    "country": country,
                    "date": date,
                    "name": name,
                    }
weather_api_df = pd.DataFrame(weather_api_dict)
weather_api_df
# Out:
#          lat       lon  max_temp  humidity  wind_speed  cloudiness country  \
# 0   -18.1853   31.5519     54.03        61        5.35           0      ZW
# 1   -34.4187   19.2345     61.81        92       10.40          82      ZA
# 2   -21.2000 -175.2000     73.56        94       12.66         100      TO
# 3    -9.0656  -68.6569     78.57        70        0.89          94      BR
# 4    13.0833  109.3000     76.10        92        9.42          99      VN
# ..       ...       ...       ...       ...         ...         ...     ...
# 591 -28.5500   16.4333     59.04        89        6.49          99      NA
# 592  -9.5333  -77.5333     56.34        77        4.05          97      PE
# 593  -4.4500   26.6667     67.73        77        3.02           8      CD
# 594  -0.9492  100.3543     71.65        78        3.49         100      ID
# 595  63.0500  179.3167     32.65        44        5.61           7      RU
#
#            date            name
# 0    1665355588       Marondera
# 1    1665355589        Hermanus
# 2    1665355589           Vaini
# 3    1665355589  Sena Madureira
# 4    1665355589         Tuy Hoa
# ..          ...             ...
# 591  1665355761      Oranjemund
# 592  1665355762          Huaraz
# 593  1665355762         Kasongo
# 594  1665355763          Padang
# 595  1665355641    Beringovskiy
#
# [596 rows x 9 columns]

# %%
weather_api_df.count()
# Out:
# lat           596
# lon           596
# max_temp      596
# humidity      596
# wind_speed    596
# cloudiness    596
# country       596
# date          596
# name          596
# dtype: int64

# %%
# Output File (CSV)
weather_api_df.to_csv = ("WeatherPy\output_data\cities.csv")

# %%
weather_api_df
# Out:
#          lat       lon  max_temp  humidity  wind_speed  cloudiness country  \
# 0   -18.1853   31.5519     54.03        61        5.35           0      ZW
# 1   -34.4187   19.2345     61.81        92       10.40          82      ZA
# 2   -21.2000 -175.2000     73.56        94       12.66         100      TO
# 3    -9.0656  -68.6569     78.57        70        0.89          94      BR
# 4    13.0833  109.3000     76.10        92        9.42          99      VN
# ..       ...       ...       ...       ...         ...         ...     ...
# 591 -28.5500   16.4333     59.04        89        6.49          99      NA
# 592  -9.5333  -77.5333     56.34        77        4.05          97      PE
# 593  -4.4500   26.6667     67.73        77        3.02           8      CD
# 594  -0.9492  100.3543     71.65        78        3.49         100      ID
# 595  63.0500  179.3167     32.65        44        5.61           7      RU
#
#            date            name
# 0    1665355588       Marondera
# 1    1665355589        Hermanus
# 2    1665355589           Vaini
# 3    1665355589  Sena Madureira
# 4    1665355589         Tuy Hoa
# ..          ...             ...
# 591  1665355761      Oranjemund
# 592  1665355762          Huaraz
# 593  1665355762         Kasongo
# 594  1665355763          Padang
# 595  1665355641    Beringovskiy
#
# [596 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_api_df['humidity'].max()
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_api_df["lat"], weather_api_df["max_temp"])

plt.title("City Latitude vs. Max Temperature (10/9/22)")
plt.xlabel("Laitude")
plt.ylabel("Max Temperature (F)")

# Save the plotted figure as .pngs
plt.savefig("output_data/Latitude vs. Temperature Plot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_api_df["lat"], weather_api_df["humidity"])

plt.title("City Latitude vs. Humidity (10/09/22)")
plt.xlabel("Laitude")
plt.ylabel("Humidity (%)")

# Save the plotted figure as .pngs
plt.savefig("output_data/Latitude vs. Humidity Plot.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_api_df["lat"], weather_api_df["cloudiness"])

plt.title("City Latitude vs. Cloudiness (10/09/22)")
plt.xlabel("Laitude")
plt.ylabel("Cloudiness (%)")

# Save the plotted figure as .pngs
plt.savefig("output_data/Latitude vs. Cloudiness Plot.png")

# %%
print(weather_api_df['cloudiness'].min())
print(weather_api_df['cloudiness'].max())
# Out:
# 0
# 100

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed scatter plot
plt.scatter(weather_api_df["lat"], weather_api_df["wind_speed"])

plt.title("City Latitude vs. Wind Speed (mph) (10/09/22)")
plt.xlabel("Laitude")
plt.ylabel("Wind Speed (%)")

# Save the plotted figure as .pngs
plt.savefig("output_data/Latitude vs. Wind Speed Plot.png")

# %% [markdown]
# ## Linear Regression

# %%
# Separate Northern and Southern Hemispheres in dataframes

n_df = weather_api_df.loc[weather_api_df["lat"] >= 0]
s_df = weather_api_df.loc[weather_api_df["lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = n_df['lat']
y_values = n_df['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.6801478701352346

# %% [markdown]
# <span style="color: red;">This graph is displaying a relationship between temperature and latitude location. As the latitude coordinates grow then max tempurature of the city decrease.</span>

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = s_df['lat']
y_values = s_df['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.5573087813682839

# %% [markdown]
# <span style="color: red;">This graph is displaying a relationship between temperature and latitude location. As the latitude coordinates grow then max tempurature of the city increase.</span>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = n_df['lat']
y_values = n_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.0025715767007526264

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between humidity and latitude location.</span>

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = s_df['lat']
y_values = s_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.034268535438353

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between humidity and latitude location.</span>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = n_df['lat']
y_values = n_df['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.013612565463361297

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between cloudiness and latitude location.</span>

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = s_df['lat']
y_values = s_df['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.005289299720124189

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between cloudiness and latitude location.</span>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = n_df['lat']
y_values = n_df['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.05124922388739072

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between windspeed and latitude location.</span>

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = s_df['lat']
y_values = s_df['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (10/09/22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue**2}")
plt.show()

# Save the plotted figure as .pngs
plt.savefig("output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.025567877881534716

# %% [markdown]
# <span style="color: red;">This graph is displaying that there is no relationship between windspeed and latitude location.</span>
